# %% [markdown]
# <div class="html">
# <h1> Vorlesung Machine Learning TIB (Hochschule Esslingen) SS20 </h1>
# <h2> Laborübung 1</h2>
# </div>
#
# <div align="right">
# Tim Hilt<br>
# Markus Maisch<br>
# Emil Slomka
# </div>

# %% [markdown]
# ## Setup

# %% [markdown]
# Be sure that `numpy`  and `matplotlib` are installed in your environment.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
print(f'Installed version of Numpy: {np.__version__}')
# Out:
# Installed version of Numpy: 1.18.1

# %% [markdown]
# ## Distance point to plane

# %% [markdown]
# Implement a function that computes the distance of a point to a plane in a $n$-dimensional
# space. The plane should be given by **some** normal vector and its distance to the origin.

# %% [markdown]
# ### Implementation

# %% [markdown]
# Implement the following function

# %%
def dist(nv, d, q):
        """
        Return the distance of the plane given by (nv, d) from point q.

        Args:
           nv (np.array): a normal vector
           d  (float): distance of plane to origin
           q (np.array: point

        Returns:
           non-negative distance
        """
        # TODO
        return -1.0

# %% [markdown]
# ### Implement a unit test

# %% [markdown]
# Run the following **unit test** ([wikipedia](https://en.wikipedia.org/wiki/Unit_testing)) (which currently fails, excecute the
#     cell to see this):

# %%
def test_dist1():
    nv = np.array((1,1))
    d = 0
    np.testing.assert_almost_equal(dist(nv, 0, np.array((1,1))),  np.sqrt(2))

test_dist1()

# %% [markdown]
# ### Implement additional unit tests

# %% [markdown]
# Provide two additional unit tests with dimension two and three and $d \neq 0$.

# %%
def test_dist2():
    assert False

def test_dist2():
    assert False

test_dist2()
test_dist3()

# %% [markdown]
# ### Implement signed distance

# %% [markdown]
# Your function returns always a non-negative value. Can you modify your
# function to return a **signed** distance? What is the interpretation of
# this signed distance ?

# %% [markdown]
# ## Newton's Method

# %% [markdown]
# Newton&rsquo;s method can be used to find the root of a polynomial.
# Suppose you want to solve the following equation for some  differentiable function $f$:
# $$
# f(x) = 0
# $$
# Newton&rsquo;s method starts a randomly chosen point $x_0$ *near* the solution. Then it computes the sequence
# $$
# x_{n+1} = x_n - \frac{f(x_n)}{f'(x_n)}
# $$
# which (hopefully) converges to the solution.
# Implement this method and test it to find the root of the polynomial
# $$
# f(x) = x^4 - 3 x^2 - x- 2.
# $$
# Note: You have to approximate $f'(x_n)$ with the **difference quotient** (there is
# more than one way to do this).

# %% [markdown]
# ### Plot

# %% [markdown]
# Plot the function $f$ in the interval $(-2.5, 2.5)$ to find a good starting
# value $x_0$.

# %% [markdown]
# ### Implement the function:

# %%
def newton(f, x0, n_iter):
        """
        Newton approximation.

        Args:
          f: function, should has an () operator
          x0: starting point
          n_iter: number of iterations w
        Returns:
          Root of function $x$, i.e. f(x) = 0
        """
        pass

# %% [markdown]
# ### Unit tests

# %% [markdown]
# Provide three `unit tests` for your implementation.
# Two of them should use function $f$. The third one should utilize another polynomial.

# %%
def test_newton1():
    assert False

def test_newton2():
    assert False

def test_newton3():
    assert False

test_newton1()
test_newton2()
test_newton3()

# %% [markdown]
# ### Extended implementation

# %% [markdown]
# Extend your implementation of **Newton iteration:**
#
# -   If after running for `n_iter` iterations, the solution $x_n$ is not
#     close to a root, raise an `exception`.
# -   Implement a unit test, that assures that such exception is raised.

# %% [markdown]
# ### Optional part

# %% [markdown]
# Try to explore how the final solution depends on the starting point.
